# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0]
SRC_DIR = PROJECT_ROOT / "src"

sys.path.insert(0, str(SRC_DIR))

print("PROJECT_ROOT:", PROJECT_ROOT)
print("SRC_DIR:", SRC_DIR)
print("SRC exists:", SRC_DIR.exists())
# Out:
# PROJECT_ROOT: c:\Users\User\Documents\estudo_DS
# SRC_DIR: c:\Users\User\Documents\estudo_DS\src
# SRC exists: True

# %%
import ds_core
print("ds_core carregado de:", ds_core.__file__)
# Out:
# ds_core carregado de: c:\Users\User\Documents\estudo_DS\src\ds_core\__init__.py

# %%
from ds_core.paths import RAW_DATA_DIR, DATA_DIR, OUTPUT_DIR

print("DATA_DIR:", DATA_DIR)
print("RAW_DATA_DIR:", RAW_DATA_DIR)
print("OUTPUT_DIR:", OUTPUT_DIR)
# Out:
# DATA_DIR: C:\Users\User\Documents\estudo_DS\data
# RAW_DATA_DIR: C:\Users\User\Documents\estudo_DS\data\raw
# OUTPUT_DIR: C:\Users\User\Documents\estudo_DS\outputs
