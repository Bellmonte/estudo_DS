# %%
from ds_core.paths import (
    RAW_DATA_DIR,
    INTERIM_DATA_DIR,
    PROCESSED_DATA_DIR,
    EXTERNAL_DATA_DIR,
    NOTEBOOKS_DIR,
    OUTPUT_DIR
)

import pandas as pd

# %%
df = pd.read_csv(
    RAW_DATA_DIR / "curso_1" / "estatistica_descritiva" / "analise_imoveis_sao_paulo.csv", sep=";", header=0
)

# %%
df
# Out:
#        Unnamed: 0                             Rua               Bairro  \
# 0               0           Avenida Itacira, 255     Planalto Paulista
# 1               1  Rua Aurelia Perez Alvarez, 42    Jardim dos Estados
# 2               2                Rua Alba Valdez       Jardim Reimberg
# 3               3      Jardim Morumbi, São Paulo                    SP
# 4               4        Rua Tobias Barreto, 195                 Mooca
# ...           ...                             ...                  ...
# 10028       10028                     Rua Tapuçu            Vila Sofia
# 10029       10029                  Rua Guararema       Bosque da Saúde
# 10030       10030              Rua Estero Belaco         Vila da Saúde
# 10031       10031         Rua Manuel Onha, , 514         Vila Oratório
# 10032       10032      Rua Barão de Tramandaí, 0           Vila Alpina
#
#             Cidade  area_m2 quartos banheiros vagas  \
# 0       São Paulo      1000       4         8     6
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10033 entries, 0 to 10032
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10033 non-null  int64
#  1   Rua         10033 non-null  str
#  2   Bairro      10033 non-null  str
#  3   Cidade      6559 non-null   str
#  4   area_m2     10033 non-null  str
#  5   quartos     10033 non-null  str
#  6   banheiros   10033 non-null  str
#  7   vagas       10033 non-null  str
#  8   price       10033 non-null  str
# dtypes: int64(1), str(8)
# memory usage: 705.6 KB

# %%
df.sample(n=100)
# Out:
#       Unnamed: 0                                      Rua             Bairro  \
# 4020        4020                    Rua Domingos Barreto      Jardim Everest
# 6636        6636                        Rua Matilde Diez     Vila do Castelo
# 4042        4042                Jardim Europa, São Paulo                  SP
# 4400        4400  Rua Comandante Ismael Guilherme, , 537    Jardim Luzitânia
# 9154        9154                         Avenida Morumbi             Morumbi
# ...          ...                                      ...                ...
# 6091        6091               Rua Elizabeth Trovão Usui        Vila Olímpia
# 3591        3591                              Rua Croata        Vila Ipojuca
# 4790        4790                             Rua Valença              Sumaré
# 4777        4777                Cidade Jardim, São Paulo                  SP
# 6235        6235          Rua João Batista Leme da Silva       Vila Madalena
#
# ...

# %%
colunas = list(df.columns)

for coluna in colunas:
    print(f"Percentual de linhas com valor nulo na coluna '{coluna}': {df[coluna].isnull().mean() * 100:.2f}%")
# Out:
# Percentual de linhas com valor nulo na coluna 'Unnamed: 0': 0.00%
# Percentual de linhas com valor nulo na coluna 'Rua': 0.00%
# Percentual de linhas com valor nulo na coluna 'Bairro': 0.00%
# Percentual de linhas com valor nulo na coluna 'Cidade': 34.63%
# Percentual de linhas com valor nulo na coluna 'area_m2': 0.00%
# Percentual de linhas com valor nulo na coluna 'quartos': 0.00%
# Percentual de linhas com valor nulo na coluna 'banheiros': 0.00%
# Percentual de linhas com valor nulo na coluna 'vagas': 0.00%
# Percentual de linhas com valor nulo na coluna 'price': 0.00%

# %%
colunas_usadas = [column for column in df.columns if column != "Unnamed: 0"]

df_duplicados = df.groupby(colunas_usadas, as_index=False).size()
df_duplicados[df_duplicados["size"] > 1]
# Out:
# Empty DataFrame
# Columns: [Rua, Bairro, Cidade, area_m2, quartos, banheiros, vagas, price, size]
# Index: []

# %%
df = df.drop(columns=["Unnamed: 0"]).drop_duplicates()
